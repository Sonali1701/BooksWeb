# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonali1701/BooksWeb/blob/main/colab/drive_access_request_queue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # BooksWeb Drive viewer-access request queue
#
# Run the cell below and sign in with the Google account that should receive access. The notebook checks the restricted BooksWeb resources, removes duplicate Drive IDs, attempts to read owner names, skips items already accessible to the signed-in account, and prepares a personalized request message for each remaining item.
#
# **Google requires each access request to be submitted in the Drive UI.** The official Drive API cannot create access proposals, so the notebook provides an `Open Drive request page` button for each item instead of using unsupported private endpoints.

# %%
import requests

script_url = "https://raw.githubusercontent.com/Sonali1701/BooksWeb/main/colab/drive_access_request_queue.py"
script_response = requests.get(script_url, timeout=60)
script_response.raise_for_status()
exec(compile(script_response.text, script_url, "exec"))
